# %%
import bs4

# %%
from bs4 import BeautifulSoup

# %%
import requests

# %%
r=requests.get("https://en.wikipedia.org/wiki/Beautiful_Soup_(HTML_parser)")

# %%
r.content
# Out:
# b'<!DOCTYPE html>\n<html class="client-nojs" lang="en" dir="ltr">\n<head>\n<meta charset="UTF-8"/>\n<title>Beautiful Soup (HTML parser) - Wikipedia</title>\n<script>document.documentElement.className = document.documentElement.className.replace( /(^|\\s)client-nojs(\\s|$)/, "$1client-js$2" );</script>\n<script>(window.RLQ=window.RLQ||[]).push(function(){mw.config.set({"wgCanonicalNamespace":"","wgCanonicalSpecialPageName":false,"wgNamespaceNumber":0,"wgPageName":"Beautiful_Soup_(HTML_parser)","wgTitle":"Beautiful Soup (HTML parser)","wgCurRevisionId":790259926,"wgRevisionId":790259926,"wgArticleId":35537613,"wgIsArticle":true,"wgIsRedirect":false,"wgAction":"view","wgUserName":null,"wgUserGroups":["*"],"wgCategories":["Pages using Infobox software with unknown parameters","All stub articles","Python libraries","Software using the MIT license","HTML parsers","XML parsers","Computer library stubs"],"wgBreakFrames":false,"wgPageContentLanguage":"en","wgPageContentModel":"wikitext","wgSe
# ...

# %%
soup = BeautifulSoup(r.content,"lxml")

# %%
print (soup.prettify())
# Out:
# <!DOCTYPE html>
# <html class="client-nojs" dir="ltr" lang="en">
#  <head>
#   <meta charset="utf-8"/>
#   <title>
#    Beautiful Soup (HTML parser) - Wikipedia
#   </title>
#   <script>
#    document.documentElement.className = document.documentElement.className.replace( /(^|\s)client-nojs(\s|$)/, "$1client-js$2" );
#   </script>
#   <script>
# ...

# %%
soup.find_all("a")
# Out:
# [<a id="top"></a>,
#  <a href="#mw-head">navigation</a>,
#  <a href="#p-search">search</a>,
#  <a class="mw-redirect mw-disambig" href="/wiki/Beautiful_Soup_(disambiguation)" title="Beautiful Soup (disambiguation)">Beautiful Soup</a>,
#  <a href="/wiki/Software_developer" title="Software developer">Original author(s)</a>,
#  <a href="/wiki/Software_release_life_cycle" title="Software release life cycle">Stable release</a>,
#  <a href="/wiki/Repository_(version_control)" title="Repository (version control)">Repository</a>,
#  <a class="external free" href="https://code.launchpad.net/beautifulsoup/" rel="nofollow">https://code.launchpad.net/beautifulsoup/</a>,
# ...

# %%
for link in soup.find_all("a"):
    print (link.get("href"))
# Out:
# None
# #mw-head
# #p-search
# /wiki/Beautiful_Soup_(disambiguation)
# /wiki/Software_developer
# /wiki/Software_release_life_cycle
# /wiki/Repository_(version_control)
# https://code.launchpad.net/beautifulsoup/
# https://www.wikidata.org/wiki/Q2893296#P1324
# /wiki/Python_(programming_language)
# /wiki/Computing_platform
# /wiki/Python_(programming_language)
# /wiki/Software_categories#Broad_categories
# /wiki/HTML
# /wiki/Web_scraping
# /wiki/Software_license
# /wiki/Python_Software_Foundation_License
# /wiki/MIT_License
# #cite_note-crummy.com-1
# http://www.crummy.com/software/BeautifulSoup/
# /wiki/Python_(programming_language)
# /wiki/HTML
# /wiki/XML
# /wiki/Tag_soup
# /wiki/Web_scraping
# #cite_note-crummy.com-1
# /w/index.php?title=Beautiful_Soup_(HTML_parser)&action=edit&section=1
# /w/index.php?title=Beautiful_Soup_(HTML_parser)&action=edit&section=2
# /wiki/Comparison_of_HTML_parsers
# /w/index.php?title=Beautiful_Soup_(HTML_parser)&action=edit&section=3
# ...

# %%
print (link.text)
